# %% [markdown]
# # Coding Quiz 2025 -- Version4

# %% [markdown]
# ## Q1: Import & Data Integrity

# %%
# Q1: Import & Data Integrity
import pandas as pd

# 1. import data
df = pd.read_csv("CQ_data_mushrooms.csv")

# %%
# 2. print shape
print("shape (rows, cols):", df.shape)
# Out:
# shape (rows, cols): (8124, 23)

# %%
# 3. print head
print("\nhead:")
print(df.head())
# Out:
# head:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
# 4. print column name
print("\ncolumn name:")
print(df.columns.tolist())
# Out:
# column name:
# ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

# %%
# 5. missing value for every column
print("\nmissing value:")
print(df.isnull().sum())
# Out:
# missing value:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# 6. data type for every line
print("\ndata type:")
print(df.dtypes)
# Out:
# data type:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
# 7. number of unique value
print("\nnumber of unique value:")
print(df.nunique())
# Out:
# number of unique value:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
# 8. checking class target missing
print("\ntarget 'class' missing count:", df['class'].isnull().sum())
# Out:
# target 'class' missing count: 0

# %% [markdown]
# ## Q2: Drop One Feature with Evidence

# %%
# Q2: Drop One Feature with Evidence

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
# 1. read data in df
df = pd.read_csv("CQ_data_mushrooms.csv")

# 2. delete useless data veil-type
print("count of column before delete:", df.shape[1])
df = df.drop(columns=["veil-type"])
print("count of column after delete:", df.shape[1])

# 3. split labels
X = df.drop(columns=["class"])
y = df["class"]

# 4. One-Hot coding
encoder = OneHotEncoder(handle_unknown="ignore")
X_encoded = encoder.fit_transform(X)

# 5. build random forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_encoded, y)

# 6. output importancing (10)
importances = rf.feature_importances_
feature_names = encoder.get_feature_names_out(X.columns)

# build DataFrame sorting
importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

print("\nimportance of top 10:")
print(importance_df.head(10))
# Out:
# count of column before delete: 23
# count of column after delete: 22
#
# importance of top 10:
#                        feature  importance
# 27                      odor_n    0.086616
# 35                 gill-size_b    0.081221
# 24                      odor_f    0.069528
# 57  stalk-surface-above-ring_k    0.066996
# 36                 gill-size_n    0.054762
# 95         spore-print-color_h    0.045059
# 37                gill-color_b    0.041447
# 91                 ring-type_l    0.032241
# 61  stalk-surface-below-ring_k    0.029949
# 93                 ring-type_p    0.029818

# %% [markdown]
# ## Q3 Pseudocode for Feature Selection vs Full Model

# %% [markdown]
# ### pseudocode approach A:
# get dataset
# X, y = load_dataset()
#
# 1. Do One-Hot coding for every categories
# X_encoded = OneHotEncode(X)
#
# 2. Using RandomForest to train the model, and calculate the importances of feture
# rf = RandomForestClassifier()
# rf.fit(X_encoded, y)
# feature_importance = rf.feature_importances_
#
# 3. Sort by imortances，choose the top N features
# top_features = select_topN(X_encoded, feature_importance, N)
#
# 4. Choose N features for Logistic Regression model training
# logreg = LogisticRegression(max_iter=5000)
# logreg.fit(X_train, y_train)
#
# 5. Using training model for prediction and calculate the accuracy
# y_pred = logreg.predict(X_test)
# accuracy_A = compute_accuracy(y_test, y_pred)

# %% [markdown]
# ### pseudocode approach B:
# get dataset
# X, y = load_dataset()
#
# 1. Do One-Hot coding for every categories
# X_encoded = OneHotEncode(X)
#
# 2. Split training set and testing set
# X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, stratify=y)
#
# 3. Training GNB model
# gnb = GaussianNB()
# gnb.fit(X_train, y_train)
#
# 4. Using training model for prediction and calculate the accuracy
# y_pred = gnb.predict(X_test)
# accuracy_B = compute_accuracy(y_test, y_pred)

# %% [markdown]
# ### Comparison Step:
#
# Compare AccuracyA 和 AccuracyB
#
# If AccuracyA > AccuracyB:
#     Approach A remove redundant features and improve performance
# Else:
#     Approach B can learn well by using full model to learning, and feature selection has limited effect

# %% [markdown]
# ## Q4: Model Implementation

# %%
# Q4: Model Implementation

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# 1. read data to df
df = pd.read_csv("CQ_data_mushrooms.csv")

# 2. remove useless features veil-type
df = df.drop(columns=["veil-type"])

df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# ...

# %%
# 3. split features and targets
X = df.drop(columns=["class"])
y = df["class"]

# 4. One-Hot coding
encoder = OneHotEncoder(handle_unknown="ignore")
X_encoded = encoder.fit_transform(X)

# %%
# 5. Choose top 10 features By random forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_encoded, y)

importances = rf.feature_importances_
feature_names = encoder.get_feature_names_out(X.columns)

importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

top10_features = importance_df.head(10)
print("top 10 important features：")
print(top10_features)
# Out:
# top 10 important features：
#                        feature  importance
# 27                      odor_n    0.086616
# 35                 gill-size_b    0.081221
# 24                      odor_f    0.069528
# 57  stalk-surface-above-ring_k    0.066996
# 36                 gill-size_n    0.054762
# 95         spore-print-color_h    0.045059
# 37                gill-color_b    0.041447
# 91                 ring-type_l    0.032241
# 61  stalk-surface-below-ring_k    0.029949
# 93                 ring-type_p    0.029818

# %%
# 6. get select features
selected_features = X_encoded[:, importance_df.index[:10]]

# %%
# 7. set training and testing sets in 70/30
X_train, X_test, y_train, y_test = train_test_split(
    selected_features, y, test_size=0.3, stratify=y, random_state=42
)

# %%
# 8. Logistic Regression model training
logreg = LogisticRegression(max_iter=5000)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
# 9. Evaluating and prediction
y_pred = logreg.predict(X_test)

print("\nModel evaluation: ")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Model evaluation:
# Accuracy: 0.9782608695652174
# Confusion Matrix:
#  [[1234   29]
#  [  24 1151]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            e       0.98      0.98      0.98      1263
#            p       0.98      0.98      0.98      1175
#
#     accuracy                           0.98      2438
#    macro avg       0.98      0.98      0.98      2438
# weighted avg       0.98      0.98      0.98      2438
